# %%
import sys
sys.path.insert(0, "/home/export/sdurgut/scratch/L1DeepMETv2")
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt
import mplhep as hep
from utils.compare import plot_response, plot_resolution

# %%
baseline_deepmet = '/home/export/sdurgut/scratch/L1DeepMETv2/ckpts/config1_run4'
edge_features_deepmet_1 = '/home/export/sdurgut/scratch/L1DeepMETv2/ckpts/config2_run0'
baseline_transformet = '/home/export/sdurgut/scratch/transformet/results/config25_run1'
edge_features_deepmet_2 = '/home/export/sdurgut/scratch/L1DeepMETv2/ckpts_ttbar/config3_run0'
edge_features_transformet = '/home/export/sdurgut/scratch/transformet/results/config29_run0'

# %% [markdown]
# # Baseline L1DeepMETv2

# %%
folders=[baseline_deepmet]
labels=['baseline L1DeepMETv2']
plot_response(folders, labels=labels, show=True)
plot_resolution(folders, labels=labels, show=True)

# Edge features L1DeepMETv2
folders=[edge_features_deepmet_1]

# %% [markdown]
# # Baseline L1 DeepMETv2 vs TransforMET

# %%
folders = [baseline_deepmet, baseline_transformet]
labels = ['baseline L1DeepMETv2', 'baseline TransforMET']
plot_response(folders, labels=labels, show=True)
plot_resolution(folders, labels=labels, show=False)

# %% [markdown]
# # Baseline L1 DeepMETv2 vs TransforMET vs edge features L1DeepMETv2

# %%
folders = [baseline_deepmet, baseline_transformet, edge_features_deepmet_2, tr]
labels = ['baseline L1DeepMETv2', 'baseline TransforMET', 'L1DeepMETv2 with edge features']
plot_response(folders, labels=labels, show=True)
plot_resolution(folders, labels=labels, show=False)

# %%
folders = [baseline_deepmet, edge_features_deepmet_1, baseline_transformet, edge_features_deepmet_2]
labels = ['baseline_deepmet', 'edge_features_deepmet', 'baseline_transformet', 'edge_features_deepmet_2']
plot_response(folders, labels=labels, puppi=True, out='.')
# Out:
# Saved ./response_comparison.png

# %%
plot_resolution(folders, labels=labels, puppi=True)

# %%
config1 = '/home/export/sdurgut/scratch/transformet/results/config1_run0'
config2 = '/home/export/sdurgut/scratch/transformet/results/config2_run0'
config3 = '/home/export/sdurgut/scratch/transformet/results/config3_run0'
config4 = '/home/export/sdurgut/scratch/transformet/results/config4_run0'
config5 = '/home/export/sdurgut/scratch/transformet/results/config5_run0'
config6 = '/home/export/sdurgut/scratch/transformet/results/config6_run0'
config7 = '/home/export/sdurgut/scratch/transformet/results/config7_run0'
config8 = '/home/export/sdurgut/scratch/transformet/results/config8_run0'
config10 = '/home/export/sdurgut/scratch/transformet/results/config10_run0'
config11 = '/home/export/sdurgut/scratch/transformet/results/config11_run0'
config12 = '/home/export/sdurgut/scratch/transformet/results/config12_run0'
config13 = '/home/export/sdurgut/scratch/transformet/results/config13_run0'
config14 = '/home/export/sdurgut/scratch/transformet/results/config14_run0'
config15 = '/home/export/sdurgut/scratch/transformet/results/config15_run0'
config16 = '/home/export/sdurgut/scratch/transformet/results/config16_run0'
config17 = '/home/export/sdurgut/scratch/transformet/results/config17_run0'
config18 = '/home/export/sdurgut/scratch/transformet/results/config18_run0'
config19 = '/home/export/sdurgut/scratch/transformet/results/config19_run0'
config20 = '/home/export/sdurgut/scratch/transformet/results/config20_run0'
config21 = '/home/export/sdurgut/scratch/transformet/results/config21_run0'
config22 = '/home/export/sdurgut/scratch/transformet/results/config22_run0'
config23 = '/home/export/sdurgut/scratch/transformet/results/config23_run0'
config24 = '/home/export/sdurgut/scratch/transformet/results/config24_run0'
config25 = '/home/export/sdurgut/scratch/transformet/results/config25_run0'
config26 = '/home/export/sdurgut/scratch/transformet/results/config26_run0'
config27 = '/home/export/sdurgut/scratch/transformet/results/config27_run0'
config28 = '/home/export/sdurgut/scratch/transformet/results/config28_run0'
config29 = '/home/export/sdurgut/scratch/transformet/results/config29_run0'
config30 = '/home/export/sdurgut/scratch/transformet/results/config30_run0'
config31 = '/home/export/sdurgut/scratch/transformet/results/config31_run0'
config32 = '/home/export/sdurgut/scratch/transformet/results/config32_run0'

# %%
folders = [config1, config2, config3, config4, config5, config6]
labels = ['config1', 'config2', 'config3', 'config4', 'config5', 'config6']
plot_resolution(folders, labels=labels, show=False)

# %%
#config 2 : best resolution in perpendicular direction

# %%
folders = [config7, config8, config10, config11, config12]
labels = ['config7', 'config8', 'config9', 'config10', 'config11', 'config12']
plot_resolution(folders, labels=labels, show=False)

# %%
#config11 : best resolution in perpendicular direction
folders = [config12, config13, config14, config15, config16, config17, config18]
labels = ['config12', 'config13', 'config14', 'config15', 'config16', 'config17', 'config18']
plot_resolution(folders, labels=labels, show=False)

# %%
#config16: best res in perpendicular direction
folders = [config17, config21]
labels = ['config17', 'config21']
plot_resolution(folders, labels=labels, show=False)

#config 21: best res in perpendicular direction

# %%
# now the bests 
folders = [config2, config11, config16, config21]
labels = ['config2', 'config11', 'config16', 'config21']
plot_resolution(folders, labels=labels, show=False)

# %%
#config21 vs deepmet 
folders = [config21, edge_features_deepmet_1, edge_features_deepmet_2]
labels = ['config21', 'edge_features_deepmet_1', 'edge_features_deepmet_2']
plot_resolution(folders, labels=labels, show=False)

# %%
folders = [baseline_deepmet, edge_features_deepmet_1, edge_features_deepmet_2]
labels = ['baseline_deepmet', 'edge_features_deepmet_1', 'edge_features_deepmet_2']
plot_resolution(folders, labels=labels, show=True)
plot_response(folders, labels=labels, show=False)

# %%
folders = [baseline_deepmet, baseline_transformet, edge_features_deepmet_2, edge_features_transformet]
labels = ['baseline L1DeepMETv2', 'baseline TransforMET', 'L1DeepMETv2 with edge features', 'TransforMET with edge features']
plot_response(folders, labels=labels, show=True)
plot_resolution(folders, labels=labels, show=False)
